# %%
import pandas as pd

# %%
url = 'https://www.formula1.com/en/results.html/2021/drivers.html'

# %%
standings = pd.read_html(url)

# %%
standings[0]
# Out:
#     Unnamed: 0  Pos                    Driver Nationality  \
# 0          NaN    1      Max  Verstappen  VER         NED
# 1          NaN    2      Lewis  Hamilton  HAM         GBR
# 2          NaN    3     Valtteri  Bottas  BOT         FIN
# 3          NaN    4        Sergio  Perez  PER         MEX
# 4          NaN    5        Carlos  Sainz  SAI         ESP
# 5          NaN    6        Lando  Norris  NOR         GBR
# 6          NaN    7     Charles  Leclerc  LEC         MON
# 7          NaN    8    Daniel  Ricciardo  RIC         AUS
# 8          NaN    9        Pierre  Gasly  GAS         FRA
# 9          NaN   10     Fernando  Alonso  ALO         ESP
# 10         NaN   11        Esteban  Ocon  OCO         FRA
# 11         NaN   12    Sebastian  Vettel  VET         GER
# 12         NaN   13        Lance  Stroll  STR         CAN
# 13         NaN   14        Yuki  Tsunoda  TSU         JPN
# 14         NaN   15      George  Russell  RUS         GBR
# ...

# %%
standings = standings[0].drop(columns=['Unnamed: 0', 'Unnamed: 6'])

# %%
standings
# Out:
#     Pos                    Driver Nationality                        Car  \
# 0     1      Max  Verstappen  VER         NED      Red Bull Racing Honda
# 1     2      Lewis  Hamilton  HAM         GBR                   Mercedes
# 2     3     Valtteri  Bottas  BOT         FIN                   Mercedes
# 3     4        Sergio  Perez  PER         MEX      Red Bull Racing Honda
# 4     5        Carlos  Sainz  SAI         ESP                    Ferrari
# 5     6        Lando  Norris  NOR         GBR           McLaren Mercedes
# 6     7     Charles  Leclerc  LEC         MON                    Ferrari
# 7     8    Daniel  Ricciardo  RIC         AUS           McLaren Mercedes
# 8     9        Pierre  Gasly  GAS         FRA           AlphaTauri Honda
# 9    10     Fernando  Alonso  ALO         ESP             Alpine Renault
# 10   11        Esteban  Ocon  OCO         FRA             Alpine Renault
# 11   12    Sebastian  Vettel  VET         GER      Aston Martin Mercedes
# ...
